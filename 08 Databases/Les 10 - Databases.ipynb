# %% [markdown]
# # Les 10 - databases
#
# Werk met Xampp https://www.apachefriends.org/ of mamp (macOS) https://www.mamp.info/en/windows/
# of Laragon https://laragon.org/ (Windows, lichter dan Xampp)
#
# Installeer https://pypi.org/project/mysql-connector-python/

# %%
! py -m pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.7.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Downloading mysql_connector_python-9.7.0-cp314-cp314-win_amd64.whl (18.2 MB)
#    ---------------------------------------- 0.0/18.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/18.2 MB 8.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 2.1/18.2 MB 8.4 MB/s eta 0:00:02
#    -------- ------------------------------- 3.9/18.2 MB 8.8 MB/s eta 0:00:02
#    ------------ --------------------------- 5.8/18.2 MB 8.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 8.1/18.2 MB 9.0 MB/s eta 0:00:02
#    --------------------- ------------------ 10.0/18.2 MB 8.9 MB/s eta 0:00:01
#    ------------------------- -------------- 11.8/18.2 MB 8.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.6/18.2 MB 8.9 MB/s eta 0:00:01
#    --------------------------------- ------ 15.2/18.2 MB 8.8 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.2 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 18.2/18.2 MB 8.5 MB/s  0:00:02
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.7.0
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Connectie met de databank
#
# Bij standaardinstallatie
# - username : root
# - paswoord :
#
# Altijd wachtwoord aanpassen als je gaat deployen!

# %%
import mysql.connector

db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="movies_db"
)

cursor = db.cursor()

# eender wat gaan doen ;)

print(db.connection_id)

cursor.close()
db.close()
# Out:
# 11

# %% [markdown]
# ## READ table

# %%
import mysql.connector

db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="movies_db"
)

cursor = db.cursor()
query = 'SELECT * FROM actors WHERE NAME LIKE "%u%"'
cursor.execute(query)

actors = cursor.fetchall();

print(actors)
for actor in actors:
    print(actor[1])

# eender wat gaan doen ;)

print(db.connection_id)

cursor.close()
db.close()
# Out:
# [(3, 'Jamie Lee Curtis'), (4, 'Tom Cruise')]
# Jamie Lee Curtis
# Tom Cruise
# 11

# %%
import mysql.connector

db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="movies_db"
)

cursor = db.cursor()

query = "SELECT name, title FROM actors a JOIN movie_actor ma ON a.id = ma.actor_id JOIN movies m ON ma.movie_id = m.id"

cursor.execute(query)

data = cursor.fetchall()

for item in data:
    print(item)

cursor.close()
db.close()
# Out:
# ('Michelle Yeoh', 'Everything Everywhere All at Once')
# ('Stephan James', 'Everything Everywhere All at Once')
# ('Jamie Lee Curtis', 'Everything Everywhere All at Once')
# ('Tom Cruise', 'Top Gun: Maverick')

# %% [markdown]
# ## INSERT records in table

# %%
import mysql.connector

db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="movies_db"
)

cursor = db.cursor()

query = "INSERT INTO movies (title, synopsis) VALUES (%s,%s)"
data = ("BLABLA","Dit is een BLABLA film")

cursor.execute(query, data)

db.commit() # SUPER BELANGRIJK!!!!

cursor.close()
db.close()

# %% [markdown]
# ## Scrapen data in database
#
# https://yougov.com/en-us/ratings/all-time-actors-actresses
#
#
# scrapen top 100 actors naar actors-tabel

# %%
# stap 1 : scrapen --> zorg dat je uberhaupt de data te pakken krijgt!!!!

import requests
from bs4 import BeautifulSoup

url = "https://yougov.com/en-us/ratings/all-time-actors-actresses"
headers = {'User-agent': 'Mozilla/5.0'} 

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text)

# <span _ngcontent-yg-app-c318061963="" class="entity-name multi-word">Betty White</span>

data = []
actors = soup.find_all("span",attrs={"class":"entity-name multi-word"})
for actor in actors:
    print(actor.getText()) # of contents
    data.append(actor.contents)

print(data)
# Out:
# Robin Williams
# Betty White
# Keanu Reeves
# Samuel L. Jackson
# Morgan Freeman
# Bruce Willis
# Denzel Washington
# Michael J. Fox
# Tom Hanks
# James Earl Jones
# Jackie Chan
# Harrison Ford
# Bruce Lee
# Danny DeVito
# Robert Downey Jr.
# Nicolas Cage
# Sandra Bullock
# Jim Carrey
# Eddie Murphy
# Adam Sandler
# [['Robin Williams'], ['Betty White'], ['Keanu Reeves'], ['Samuel L. Jackson'], ['Morgan Freeman'], ['Bruce Willis'], ['Denzel Washington'], ['Michael J. Fox'], ['Tom Hanks'], ['James Earl Jones'], ['Jackie Chan'], ['Harrison Ford'], ['Bruce Lee'], ['Danny DeVito'], ['Robert Downey Jr.'], ['Nicolas Cage'], ['Sandra Bullock'], ['Jim Carrey'], ['Eddie Murphy'], ['Adam Sandler']]

# %%
import mysql.connector

db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="movies_db"
)

cursor = db.cursor()

query = "INSERT INTO actors (name) VALUES (%s)"
for actor in data:
    cursor.execute(query, actor)

db.commit() # SUPER BELANGRIJK!!!!

cursor.close()
db.close()
