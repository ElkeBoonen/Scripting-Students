# %% [markdown]
# # Dit is mijn demo-file
#
# Hierin ga ik al mijn kunstjes tonen én laten zien hoe cool mijn package eigenlijk is ;)

# %%
from mypackage import text, mathematic

# text functies
print(text.novowels("appel"))
print(text.novowels("kiwi"))
print(text.reverse("kiwi"))
print(text.reverse("lepel"))

# wiskundige functies

print(mathematic.sumofmulti(2))
print(mathematic.sumofmulti(100))
print(mathematic.sumofmulti(1.5))
# Out:
# ppl
# kw
# iwik
# lepel
# 90
# 4500
# 67.5

# %% [markdown]
# Demonstratie van de help-functionaliteit

# %%
help(mathematic)
help(text.reverse)
# Out:
# Help on module mypackage.mathematic in mypackage:
#
# NAME
#     mypackage.mathematic
#
# FUNCTIONS
#     sumofmulti(number)
#         Returns the sum of the multiplication table
#         Parameters:
#             a number
#         Returns:
#             a number
#
# FILE
#     c:\users\u0116591\onedrive - thomas more\github 24-25\scripting-students\10 packages\mypackage\mathematic.py
#
#
# Help on function reverse in module mypackage.text:
#
# reverse(word)
#     Returns a reversed word
#     Parameters:
#         a string
#     Returns:
#         a string
